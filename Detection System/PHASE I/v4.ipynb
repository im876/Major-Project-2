# %% [markdown]
# # Import Statements

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data list for storing image data in numpy array form
# 2. paths list for storing paths of all images
# 3. result list for storing one hot encoded form of target class whether normal or tumor

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'../input/augmented-dataset/yes/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../input/augmented-dataset/no/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (2063, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(2063,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax', metrics = ["accuracy"])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (1650, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 42/42 [==============================] - 58s 1s/step - loss: 7.4475 - accuracy: 0.6582 - val_loss: 0.7264 - val_accuracy: 0.6465
# Epoch 2/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.5606 - accuracy: 0.7703 - val_loss: 0.5615 - val_accuracy: 0.7530
# Epoch 3/30
# 42/42 [==============================] - 70s 2s/step - loss: 0.3962 - accuracy: 0.8079 - val_loss: 0.5257 - val_accuracy: 0.7651
# Epoch 4/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.3293 - accuracy: 0.8467 - val_loss: 0.5306 - val_accuracy: 0.7748
# Epoch 5/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.3167 - accuracy: 0.8564 - val_loss: 0.5984 - val_accuracy: 0.7845
# Epoch 6/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.2648 - accuracy: 0.8879 - val_loss: 0.6895 - val_accuracy: 0.7918
# Epoch 7/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.2247 - accuracy: 0.9006 - val_loss: 0.7284 - val_accuracy: 0.7869
# Epoch 8/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.1892 - accuracy: 0.9236 - val_loss: 0.7573 - val_accuracy: 0.7893
# Epoch 9/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.1752 - accuracy: 0.9267 - val_loss: 0.8536 - val_accuracy: 0.7821
# Epoch 10/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.1444 - accuracy: 0.9406 - val_loss: 0.8477 - val_accuracy: 0.7869
# Epoch 11/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.1313 - accuracy: 0.9533 - val_loss: 0.8654 - val_accuracy: 0.7893
# Epoch 12/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.1236 - accuracy: 0.9588 - val_loss: 0.9115 - val_accuracy: 0.7942
# Epoch 13/30
# 42/42 [==============================] - 72s 2s/step - loss: 0.1121 - accuracy: 0.9582 - val_loss: 0.9085 - val_accuracy: 0.7990
# Epoch 14/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0859 - accuracy: 0.9733 - val_loss: 0.8465 - val_accuracy: 0.8087
# Epoch 15/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0835 - accuracy: 0.9758 - val_loss: 0.8394 - val_accuracy: 0.7918
# Epoch 16/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0698 - accuracy: 0.9758 - val_loss: 0.9190 - val_accuracy: 0.8039
# Epoch 17/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0671 - accuracy: 0.9788 - val_loss: 0.8944 - val_accuracy: 0.7966
# Epoch 18/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.0497 - accuracy: 0.9891 - val_loss: 0.9111 - val_accuracy: 0.8039
# Epoch 19/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.0449 - accuracy: 0.9879 - val_loss: 0.8514 - val_accuracy: 0.8111
# Epoch 20/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0520 - accuracy: 0.9855 - val_loss: 1.0484 - val_accuracy: 0.7966
# Epoch 21/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0407 - accuracy: 0.9867 - val_loss: 0.8809 - val_accuracy: 0.8087
# Epoch 22/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0454 - accuracy: 0.9873 - val_loss: 0.9684 - val_accuracy: 0.8087
# Epoch 23/30
# 42/42 [==============================] - 61s 1s/step - loss: 0.0368 - accuracy: 0.9885 - val_loss: 0.8666 - val_accuracy: 0.8039
# Epoch 24/30
# 42/42 [==============================] - 66s 2s/step - loss: 0.0349 - accuracy: 0.9933 - val_loss: 0.9002 - val_accuracy: 0.8039
# Epoch 25/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.0303 - accuracy: 0.9921 - val_loss: 0.9845 - val_accuracy: 0.7990
# Epoch 26/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.0238 - accuracy: 0.9939 - val_loss: 0.9246 - val_accuracy: 0.8136
# Epoch 27/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0214 - accuracy: 0.9945 - val_loss: 0.9040 - val_accuracy: 0.8039
# Epoch 28/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0198 - accuracy: 0.9958 - val_loss: 0.9210 - val_accuracy: 0.8111
# Epoch 29/30
# 42/42 [==============================] - 58s 1s/step - loss: 0.0212 - accuracy: 0.9933 - val_loss: 0.9290 - val_accuracy: 0.8087
# Epoch 30/30
# 42/42 [==============================] - 57s 1s/step - loss: 0.0197 - accuracy: 0.9952 - val_loss: 1.0134 - val_accuracy: 0.7966

# %%
model.save("brain_tumor.model", save_format="h5")

# %%
history = model.history.history

# %%
for key in history.keys():
    print(key)
# Out:
# loss
# accuracy
# val_loss
# val_accuracy

# %% [markdown]
# # Plotting Losses

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    plt.figure(figsize=(15,5))
    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    
    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
plot_metrics(history)

# %% [markdown]
# # Just Checking the Model

# %%
from tensorflow.keras.models import Model, load_model
loadmodel = load_model(filepath='./brain_tumor.model')

# %%
loadmodel.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
loss, acc = loadmodel.evaluate(x=x_test, y=y_test)
# Out:
# 13/13 [==============================] - 3s 205ms/step - loss: 1.0134 - accuracy: 0.7966

# %%
print (f"Test Loss = {loss}")
print (f"Test Accuracy = {acc}")
# Out:
# Test Loss = 1.013353705406189
# Test Accuracy = 0.7966101765632629

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 80.56945204734802% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 99.99834299087524% Confidence This Is A Its a Tumor

# %% [markdown]
# # Thats It !!
